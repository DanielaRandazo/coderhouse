# %% [markdown]
# DF_Terr -- Datasets de terrorismo a nivel mundial
#
# DF_Airports -- Aeropuertos del mundo
#
# DF_We -- clima en el mundo
#
# DF_Airlines -- Aerolineas mundiales y datos de vuelos
#
# DF_IMDB -- Internet Movie DataBase

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/CoderHouse')
# Out:
# Drive already mounted at /CoderHouse; to attempt to forcibly remount, call drive.mount("/CoderHouse", force_remount=True).

# %%
# Todos mis Datasets

#esto porque las columnas de este fallaban
dtype_dict = {
    4: str,  # Columna 4
    6: str,  # Columna 6
    31: str, # Columna 31
    33: str,  # Columna 33
    61: str,  # Columna 61
    62: str, # Columna 62
    63: str,  # Columna 63
    76: str,  # Columna 76
    79: str, # Columna 79
    90: str,  # Columna 90
    92: str,  # Columna 92
    94: str, # Columna 94
    96: str,  # Columna 96
    114: str,  # Columna 114
    115: str, # Columna 115
    121: str, # Columna 121
}
DF_Terr = pd.read_csv('/CoderHouse/MyDrive/CoderHouse/globalterrorism.csv', encoding='latin-1', dtype=dtype_dict)

DF_Airports = pd.read_csv('/CoderHouse/MyDrive/CoderHouse/airports.csv')

DF_We = pd.read_csv('/CoderHouse/MyDrive/CoderHouse/weather_hourly_darksky.csv')

DF_Airlines = pd.read_csv('/CoderHouse/MyDrive/CoderHouse/Airline_Dataset.csv')

DF_IMDB = pd.read_csv('/CoderHouse/MyDrive/CoderHouse/IMDB.csv')

# %%
tipos_de_datos = DF_IMDB.dtypes

print(tipos_de_datos)
# Out:
# Unnamed: 0           int64
# index                int64
# tconst              object
# titleType           object
# primaryTitle        object
# originalTitle       object
# isAdult              int64
# startYear            int64
# endYear             object
# runtimeMinutes      object
# genres              object
# averageRating      float64
# numVotes             int64
# ordering             int64
# title               object
# region              object
# language            object
# types               object
# attributes          object
# isOriginalTitle      int64
# Description         object
# dtype: object

# %%
column_titles = DF_IMDB.columns.tolist()

# Imprime la lista de títulos de las columnas
print(column_titles)
# Out:
# ['Unnamed: 0', 'index', 'tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes', 'ordering', 'title', 'region', 'language', 'types', 'attributes', 'isOriginalTitle', 'Description']

# %%
#miro un poco el dataframe
DF_IMDB.head()
# Out:
#    Unnamed: 0  index     tconst titleType                primaryTitle  \
# 0           0      0  tt0102926     movie    The Silence of the Lambs
# 1           1      1  tt0103064     movie  Terminator 2: Judgment Day
# 2           2      3  tt0110357     movie               The Lion King
# 3           3      4  tt0110912     movie                Pulp Fiction
# 4           4      5  tt0111161     movie    The Shawshank Redemption
#
#                 originalTitle  isAdult  startYear endYear runtimeMinutes  ...  \
# 0    The Silence of the Lambs        0       1991      \N            118  ...
# 1  Terminator 2: Judgment Day        0       1991      \N            137  ...
# 2               The Lion King        0       1994      \N             88  ...
# 3                Pulp Fiction        0       1994      \N            154  ...
# 4    The Shawshank Redemption        0       1994      \N            142  ...
#
#   averageRating  numVotes  ordering                       title region  \
# ...

# %%
# Mis columnas interesantes
DF_IMDB_Col = ['index', 'titleType', 'originalTitle', 'startYear', 'runtimeMinutes', 'numVotes', 'region']

DF_IMDB_ColInt = DF_IMDB[DF_IMDB_Col]

# Muestra el DataFrame resultante
print(DF_IMDB_Col)
# Out:
# ['index', 'titleType', 'originalTitle', 'startYear', 'runtimeMinutes', 'numVotes', 'region']

# %%
#miro un poco el dataframe
DF_IMDB_ColInt.head()
# Out:
#    index titleType               originalTitle  startYear runtimeMinutes  \
# 0      0     movie    The Silence of the Lambs       1991            118
# 1      1     movie  Terminator 2: Judgment Day       1991            137
# 2      3     movie               The Lion King       1994             88
# 3      4     movie                Pulp Fiction       1994            154
# 4      5     movie    The Shawshank Redemption       1994            142
#
#    numVotes region
# 0   1473918     US
# 1   1128166     US
# 2   1090882     US
# 3   2118762     US
# 4   2759621     US

# %%
#miro filas y columnas
DF_IMDB.shape
# Out:
# (7850, 21)

# %%
#para revisar pero trae datos estadisticos
DF_IMDB.describe()
# Out:
#        Unnamed: 0         index  isAdult    startYear  averageRating  \
# count  7850.00000   7850.000000   7850.0  7850.000000    7850.000000
# mean   3924.50000   5286.804076      0.0  2013.204331       7.367605
# std    2266.24414   2851.482333      0.0     6.987697       0.605137
# min       0.00000      0.000000      0.0  1990.000000       6.500000
# 25%    1962.25000   2847.250000      0.0  2008.000000       6.900000
# 50%    3924.50000   5284.500000      0.0  2015.000000       7.300000
# 75%    5886.75000   7602.750000      0.0  2019.000000       7.800000
# max    7849.00000  10274.000000      0.0  2023.000000       9.500000
#
#            numVotes     ordering  isOriginalTitle
# count  7.850000e+03  7850.000000           7850.0
# mean   7.527845e+04    16.440382              0.0
# std    1.779794e+05    12.871290              0.0
# min    6.000000e+00     1.000000              0.0
# 25%    6.035000e+03     6.000000              0.0
# ...

# %%
# vemos la cantidad de valores nulos por cada variable
nulos_por_variable = DF_IMDB.isnull().sum()

# Imprime la cantidad de nulos por variable
print(nulos_por_variable)
# Out:
# Unnamed: 0           0
# index                0
# tconst               0
# titleType            0
# primaryTitle         0
# originalTitle        0
# isAdult              0
# startYear            0
# endYear              0
# runtimeMinutes       0
# genres               0
# averageRating        0
# numVotes             0
# ordering             0
# title                0
# region               0
# language             0
# types                0
# attributes           0
# isOriginalTitle      0
# Description        188
# dtype: int64

# %% [markdown]
# ## AHORA CON EL OTRO DATASET

# %%
tipos_de_datos = DF_Airlines.dtypes

print(tipos_de_datos)
# Out:
# Passenger ID             int64
# First Name              object
# Last Name               object
# Gender                  object
# Age                      int64
# Nationality             object
# Airport Name            object
# Airport Country Code    object
# Country Name            object
# Airport Continent       object
# Continents              object
# Departure Date          object
# Arrival Airport         object
# Pilot Name              object
# Flight Status           object
# dtype: object

# %%
#miro filas y columnas
DF_Airlines.shape
# Out:
# (98619, 15)

# %%
DF_Airlines.head()
# Out:
#    Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# ...
